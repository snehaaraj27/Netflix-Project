# %% [markdown]
# <a href="https://colab.research.google.com/github/snehaaraj27/Netflix-Project/blob/main/NETFLIX_DATASCIENCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %% [markdown]
# **Import the dataset**

# %%
import pandas as pd
data = pd.read_csv("/content/credits.csv.zip")

# %%
data
# Out:
#        person_id         id                name                character  \
# 0           3748    tm84618      Robert De Niro            Travis Bickle
# 1          14658    tm84618        Jodie Foster            Iris Steensma
# 2           7064    tm84618       Albert Brooks                      Tom
# 3           3739    tm84618       Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618     Cybill Shepherd                    Betsy
# ...          ...        ...                 ...                      ...
# 77796     736339  tm1059008    Adelaida Buscato                María Paz
# 77797     399499  tm1059008  Luz Stella Luengas             Karen Bayona
# 77798     373198  tm1059008         Inés Prieto                    Fanny
# 77799     378132  tm1059008        Isabel Gaona                   Cacica
# 77800    1950416  tm1059008      Julian Gaviria                      NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# 2         ACTOR
# 3         ACTOR
# ...

# %% [markdown]
# **Head**

# %%
data.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %% [markdown]
# **Tail**

# %%
data.tail()
# Out:
#        person_id         id                name     character      role
# 77796     736339  tm1059008    Adelaida Buscato     María Paz     ACTOR
# 77797     399499  tm1059008  Luz Stella Luengas  Karen Bayona     ACTOR
# 77798     373198  tm1059008         Inés Prieto         Fanny     ACTOR
# 77799     378132  tm1059008        Isabel Gaona        Cacica     ACTOR
# 77800    1950416  tm1059008      Julian Gaviria           NaN  DIRECTOR

# %% [markdown]
# **Shape**

# %%
data.shape
# Out:
# (77801, 5)

# %% [markdown]
# **Size**

# %%
data.size
# Out:
# 389005

# %% [markdown]
# **Columns**

# %%
data.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %% [markdown]
# **Data Type**

# %%
data.dtypes
# Out:
# person_id     int64
# id           object
# name         object
# character    object
# role         object
# dtype: object

# %% [markdown]
# **Info** Shows everthing at once

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77801 entries, 0 to 77800
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   person_id  77801 non-null  int64
#  1   id         77801 non-null  object
#  2   name       77801 non-null  object
#  3   character  68029 non-null  object
#  4   role       77801 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.0+ MB

# %% [markdown]
# **Duplicate**

# %%
data.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
data.shape
# Out:
# (77801, 5)

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 77796    False
# 77797    False
# 77798    False
# 77799    False
# 77800    False
# Length: 77801, dtype: bool

# %%
data[data.duplicated()]  # there is no duplicate data in the database
# Out:
# Empty DataFrame
# Columns: [person_id, id, name, character, role]
# Index: []

# %%
data.drop_duplicates(inplace = True) # remove the duplicate recordes

# %% [markdown]
# **Check is there any NULL values**

# %%
data.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
data.isnull()
# Out:
#        person_id     id   name  character   role
# 0          False  False  False      False  False
# 1          False  False  False      False  False
# 2          False  False  False      False  False
# 3          False  False  False      False  False
# 4          False  False  False      False  False
# ...          ...    ...    ...        ...    ...
# 77796      False  False  False      False  False
# 77797      False  False  False      False  False
# 77798      False  False  False      False  False
# 77799      False  False  False      False  False
# 77800      False  False  False       True  False
#
# [77801 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# person_id       0
# id              0
# name            0
# character    9772
# role            0
# dtype: int64

# %% [markdown]
# **Seaborn (heat map)**

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# **ISIN**

# %%
data.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
data[data["name"].isin(["Julian Gaviria"])]
# Out:
#        person_id         id            name character      role
# 77800    1950416  tm1059008  Julian Gaviria       NaN  DIRECTOR

# %% [markdown]
# **str.contains**

# %%
data["character"].str.contains("Travis Bickle")
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 77796    False
# 77797    False
# 77798    False
# 77799    False
# 77800      NaN
# Name: character, Length: 77801, dtype: object

# %%
import pandas as pd
datas = pd.read_csv("/content/netflix_titles.csv.zip")

# %%
datas.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
datas[datas['title'].str.contains("Blood & Water")]
# Out:
#   show_id     type          title director  \
# 1      s2  TV Show  Blood & Water      NaN
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 1  After crossing paths at a party, a Cape Town t...

# %% [markdown]
# **Checking heighest number of TV shows and movie relesed in which yr**

# %%
datas.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
datas['Year_n'] = pd.to_datetime(datas["release_year"])

# %%
datas.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
datas.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Year_n          datetime64[ns]
# dtype: object

# %%
datas['Year_n'].dt.year.value_counts()
# Out:
# 1970    8807
# Name: Year_n, dtype: int64

# %%
datas["Year_n"].dt.year.value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# Another metod of solving

# %%
datas.groupby("type")

# %%
datas.groupby("type").type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %% [markdown]
# **Show all the movie that where released inn the year 2000**

# %%
datas.head(1)
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
#
#                          Year_n
# 0 1970-01-01 00:00:00.000002020

# %%
datas[(datas['type']=='Movie') & (datas["release_year"]==2000)]
# Out:
#      show_id   type                                              title  \
# 180     s181  Movie                 The Nutty Professor II: The Klumps
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %% [markdown]
# **Show the titles of all TV shows that were released in India only**

# %%
datas.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          Year_n
# 0 1970-01-01 00:00:00.000002020
# ...

# %%
datas[(datas["type"]=='TV Show') & (datas['country']== 'India')] ['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %% [markdown]
# **Show the top 10 directors who gave the most number of tv shows and movie in netflix**

# %%
datas.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          Year_n
# 0 1970-01-01 00:00:00.000002020
# ...

# %%
datas['director'].value_counts().head(10)       # value_count()
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %% [markdown]
# **Show the records where "movies is Documentary" or "county in UK"**

# %%
datas.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'Year_n'],
#       dtype='object')

# %%
datas[(datas['type']=='Movie') & (datas["listed_in"]=='Documentaries')]
# Out:
#      show_id   type                                        title  \
# 0         s1  Movie                         Dick Johnson Is Dead
# 45       s46  Movie                       My Heroes Were Cowboys
# 117     s118  Movie                                Final Account
# 221     s222  Movie  Bob Ross: Happy Accidents, Betrayal & Greed
# 304     s305  Movie          Lady Boss: The Jackie Collins Story
# ...      ...    ...                                          ...
# 8723   s8724  Movie                     What Makes a Psychopath?
# 8737   s8738  Movie                   Why Are We Getting So Fat?
# 8738   s8739  Movie                                     Why Knot
# 8739   s8740  Movie           Why We Fight: The Battle of Russia
# 8763   s8764  Movie              WWII: Report from the Aleutians
#
#                                     director            cast  \
# 0                            Kirsten Johnson             NaN
# ...

# %%
datas[(datas['type']=='Movie') & (datas["listed_in"]=='Documentaries') | (datas["country"]=="United Kingdom")]
# Out:
#      show_id     type                            title         director  \
# 0         s1    Movie             Dick Johnson Is Dead  Kirsten Johnson
# 8         s9  TV Show    The Great British Baking Show  Andy Devonshire
# 32       s33  TV Show                    Sex Education              NaN
# 45       s46    Movie           My Heroes Were Cowboys      Tyler Greco
# 65       s66  TV Show                     Numberblocks              NaN
# ...      ...      ...                              ...              ...
# 8741   s8742  TV Show                      Wild Arabia              NaN
# 8744   s8745    Movie                         Williams  Morgan Matthews
# 8758   s8759  TV Show           World's Busiest Cities              NaN
# 8763   s8764    Movie  WWII: Report from the Aleutians      John Huston
# 8786   s8787    Movie                     You Can Tutu      James Brown
#
#                                                    cast         country  \
# ...

# %% [markdown]
# **Total number of movies cased by tom curues**

# %%
datas.head(1)
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
#
#                          Year_n
# 0 1970-01-01 00:00:00.000002020

# %%
datas[(datas["cast"]=='Brooke Satchwell')]
# Out:
#    show_id     type                 title director              cast  \
# 25     s26  TV Show  Love on the Spectrum      NaN  Brooke Satchwell
#
#       country          date_added  release_year rating   duration  \
# 25  Australia  September 21, 2021          2021  TV-14  2 Seasons
#
#                                          listed_in  \
# 25  Docuseries, International TV Shows, Reality TV
#
#                                           description  \
# 25  Finding love can be hard for anyone. For young...
#
#                           Year_n
# 25 1970-01-01 00:00:00.000002021

# %%
datas[datas['cast'].str.contains('Brooke Satchwell')] #this error is been cleared in the below code
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-8531478c460d> in <cell line: 1>()
# ----> 1 datas[datas['cast'].str.contains('Brooke Satchwell')]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3795
#    3796         # Do we have a (boolean) 1d indexer?
# -> 3797         if com.is_bool_indexer(key):
#    3798             return self._getitem_bool_array(key)
#    3799
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     133                     # Don't raise on e.g. ["A", "B", np.nan], see
#     134                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 135                     raise ValueError(na_msg)
#     136                 return False
#     137             return True
#
# ...

# %% [markdown]
# **Create new DataFrame**

# %%
data_new = datas.dropna()

# %%
data_new.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description  \
# ...

# %%
data_new[data_new["cast"].str.contains('Brooke Satchwell')]
# Out:
#      show_id   type             title          director  \
# 2328   s2329  Movie  Ride Like a Girl  Rachel Griffiths
#
#                                                    cast    country  \
# 2328  Teresa Palmer, Sam Neill, Sullivan Stapleton, ...  Australia
#
#          date_added  release_year rating duration  \
# 2328  June 27, 2020          2020     PG   99 min
#
#                                               listed_in  \
# 2328  Children & Family Movies, Dramas, Independent ...
#
#                                             description  \
# 2328  The daughter of a horse trainer, an ambitious ...
#
#                             Year_n
# 2328 1970-01-01 00:00:00.000002020

# %% [markdown]
# **the different ratings defined in Netflix**

# %%
datas.rating.nunique()
# Out:
# 17

# %%
datas.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# **How many movies got 'TV-14'**

# %%
datas[datas['rating']=='TV-14']
# Out:
#      show_id     type                                            title  \
# 8         s9  TV Show                    The Great British Baking Show
# 18       s19    Movie                                        Intrusion
# 20       s21  TV Show  Monsters Inside: The 24 Faces of Billy Milligan
# 21       s22  TV Show                           Resurrection: Ertugrul
# 24       s25    Movie                                            Jeans
# ...      ...      ...                                              ...
# 8772   s8773    Movie                            Yamla Pagla Deewana 2
# 8774   s8775    Movie                                        يوم الدين
# 8794   s8795    Movie                                           اشتباك
# 8799   s8800    Movie                                            Zenda
# 8806   s8807    Movie                                           Zubaan
#
#              director                                               cast  \
# ...

# %%
datas[(datas['type']=='Movie') & (datas['rating']=='TV-14')].shape
# Out:
# (1427, 13)

# %%
datas[(datas['type']=='Movie') & (datas['rating']=='TV-14') & (datas['country']=="Canada")]
# Out:
#      show_id   type                                        title  \
# 157     s158  Movie                                     Level 16
# 1279   s1280  Movie   Made You Look: A True Story About Fake Art
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5972   s5973  Movie                             #cats_the_mewvie
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8178   s8179  Movie                  The Accountant of Auschwitz
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director  \
# ...

# %%
datas[(datas['type']=='Movie') & (datas['rating']=='TV-14') & (datas['country']=="Canada")].shape
# Out:
# (13, 13)

# %% [markdown]
# **The TV Show got 'R' rating after yr 2018**

# %%
datas[(datas['type']=='TV Show') & (datas['rating']=="R") & (datas["release_year"]>2018)].shape
# Out:
# (0, 13)

# %% [markdown]
# **Finding the maximum duration of movie and show in Netfix**

# %%
datas.head(1)
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
#
#                          Year_n
# 0 1970-01-01 00:00:00.000002020

# %%
datas['duration'].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
datas.duration.dtypes
# Out:
# dtype('O')

# %%
datas.head(1)
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
#
#                          Year_n
# 0 1970-01-01 00:00:00.000002020

# %%
datas[['minitues','units']]= datas['duration'].str.split(' ', expand = True)

# %%
datas.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          Year_n minitues    units
# ...

# %%
datas['minitues'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0        90
# 1         2
# 2         1
# 3         1
# 4         2
#        ...
# 8802    158
# 8803      2
# 8804     88
# 8805     88
# 8806    111
# Name: minitues, Length: 8807, dtype: object>

# %%
datas.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Year_n          datetime64[ns]
# minitues                object
# units                   object
# dtype: object

# %% [markdown]
# **which country has the highes number of tv shows**

# %%
datas.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
data_Tvshow = datas[datas["type"]=='TV Show']

# %%
data_Tvshow.head(2)
# Out:
#   show_id     type          title         director  \
# 1      s2  TV Show  Blood & Water              NaN
# 2      s3  TV Show      Ganglands  Julien Leclercq
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description  \
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
#
#                          Year_n minitues    units
# 1 1970-01-01 00:00:00.000002021        2  Seasons
# ...

# %%
data_Tvshow.country.value_counts().head(1)
# Out:
# United States    760
# Name: country, dtype: int64

# %%
data_Tvshow.country.value_counts()
# Out:
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: country, Length: 196, dtype: int64

# %% [markdown]
# **Sort the dataset by year**

# %%
datas.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
datas.sort_values(by = 'release_year')
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# ...      ...      ...                                            ...
# 862     s863  TV Show                                        Special
# 861     s862    Movie             Little Singham Future mein Satakli
# 857     s858  TV Show                                   The Neighbor
# 876     s877  TV Show                                   Alma Matters
# 965     s966  TV Show                                         Yasuke
#
#                          director  \
# 4250                          NaN
# 7790                  Frank Capra
# ...

# %%
datas.sort_values(by = 'release_year',ascending = False)
# Out:
#      show_id     type                                          title  \
# 693     s694    Movie                         Ali & Ratu Ratu Queens
# 781     s782    Movie          Black Holes | The Edge of All We Know
# 762     s763    Movie                                   Sweet & Sour
# 763     s764  TV Show                                    Sweet Tooth
# 764     s765    Movie                   Trippin' with the Kandasamys
# ...      ...      ...                                            ...
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8763   s8764    Movie                WWII: Report from the Aleutians
# 8205   s8206    Movie                           The Battle of Midway
# 7790   s7791    Movie                                 Prelude to War
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#             director                                               cast  \
# ...

# %% [markdown]
# **Finding (Move - Documentary) or (TV Shows - kids)**

# %%
datas[(datas['type']=='Movie') | (datas['type']=='TV Show')]
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
datas[(datas['type']=='Movie') & (datas['listed_in']=="Comedies")  | (datas['type']=='TV Show') &
 (datas['listed_in'] == "Kids'TV")]
# Out:
#      show_id   type                                   title  \
# 27       s28  Movie                               Grown Ups
# 152     s153  Movie           Janoskians: Untold and Untrue
# 182     s183  Movie             Welcome Home Roscoe Jenkins
# 342     s343  Movie                             Major Payne
# 348     s349  Movie                                    Poms
# ...      ...    ...                                     ...
# 8420   s8421  Movie              The Men Who Stare at Goats
# 8433   s8434  Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537  Movie                       The Trip to Spain
# 8608   s8609  Movie                        Total Frat Movie
# 8730   s8731  Movie                       Where's the Money
#
#                   director                                               cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152           Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...

# %% [markdown]
# **Sneha Raj**
